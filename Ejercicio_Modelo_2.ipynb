# %% [markdown]
# <a href="https://colab.research.google.com/github/CynF19/Ejercicio-Modelos-2/blob/main/Ejercicio_Modelo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
from google.colab import drive
drive. mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/big_bang_theory_dataset (5).csv")
df.shape
# Out:
# (38918, 6)

# %%
import pandas as pd
import numpy as np
import xlrd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df
# Out:
#                                               Unnamed: 0  \
# 0                                                      0
# 1                                                      1
# 2      2,The room in the basement," Sheldon enters, t...
# 3                                                      3
# 4                                                      4
# ...                                                  ...
# 38913  38913,Raj’s apartment," Raj is watching a Boll...
# 38914  38914,The same," later, Leonard is dressed as ...
# 38915  38915,The hospital," Howard runs in and up to ...
# 38916                                              38916
# 38917  38917,The apartment," Sheldon has a series of ...
#
#                         Location Scene  \
# 0                  The apartment   NaN
# 1                  The apartment   NaN
# 2                            NaN   NaN
# 3      Sheldon and Amy’s bedroom   NaN
# 4                       A cinema   NaN
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0       Location Scene   Text  Speaker Season;
# count       38918          32047   135  31048    32094   32094
# unique      38918            456     9  24439        5      18
# top             0  The apartment          No.  Sheldon      8;
# freq            1           9661    49    177     9191    3760

# %%
df['Speaker']
# Out:
# 0        Leonard
# 1        Sheldon
# 2            NaN
# 3        Sheldon
# 4        Leonard
#           ...
# 38913        NaN
# 38914        NaN
# 38915        NaN
# 38916    Sheldon
# 38917        NaN
# Name: Speaker, Length: 38918, dtype: object

# %%
df.Location.value_counts()
# Out:
# The apartment                                                                                                                          9661
# Penny’s apartment                                                                                                                      2169
# The cafeteria                                                                                                                          1425
# The stairwell                                                                                                                          1136
# The comic book store                                                                                                                    791
#                                                                                                                                        ...
# At the apartment door                                                                                                                     1
# ...

# %%
import matplotlib as mpl

# %%
import pandas as pd
import numpy as np
import xlrd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
muestra=df[:10].copy()
muestra
# Out:
#                                           Unnamed: 0  \
# 0                                                  0
# 1                                                  1
# 2  2,The room in the basement," Sheldon enters, t...
# 3                                                  3
# 4                                                  4
# 5                                                  5
# 6                                                  6
# 7                                                  7
# 8                                                  8
# 9  9,The same," later,",Oh. A small human wreaks ...
#
#                                             Location Scene  \
# 0                                      The apartment   NaN
# 1                                      The apartment   NaN
# 2                                                NaN   NaN
# 3                          Sheldon and Amy’s bedroom   NaN
# 4                                           A cinema   NaN
# ...

# %%
import re

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar(['Penny', 'Sheldon', 'Raj','Howard','Leonard'], ['A bar', 'A cinema', 'The apartment','Penny’s bedroom','Sheldon and Amy’s bedroom'])
plt.show()

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/big_bang_theory_dataset (5).csv') 
df.fillna('*',inplace=True)
print(list(df))
# Out:
# ['Unnamed: 0', 'Location', 'Scene', 'Text', 'Speaker', 'Season;']

# %%
from pandas.core.arrays.categorical import contains
df[df['Text'].str.contains("Penny",case = False) & df ["Speaker"].str.contains("Sheldon",case = False)]
# Out:
#       Unnamed: 0                     Location Scene  \
# 35            35                  Penny’s car     *
# 47            47                 Penny’s door     *
# 125          125  Sheldon and Amy’s apartment     *
# 185          185                The apartment     *
# 709          709    Outside Penny’s apartment     *
# ...          ...                          ...   ...
# 38136      38136                     The same     *
# 38228      38228               Capital Comics     *
# 38326      38326                    The lobby     *
# 38708      38708            Penny’s apartment     *
# 38876      38876             The laundry room     *
#
#                                                     Text  Speaker Season;
# 35       Because he’s not like us Penny. We’re dreamers.  Sheldon      7;
# 47                                                Penny.  Sheldon      4;
# 125    This isn’t fair. You’ve discussed aspects of o...  Sheldon     10;
# ...

# %%
df=pd.DataFrame(df)
print("Veces que se pronuncia la palabra Penny")
print(df['Speaker'].max())
veces=df['Speaker'].max()
# Out:
# Veces que se pronuncia la palabra Penny
# Sheldon

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df.groupby(['Speaker']).size().reset_index(name='Season')
# Out:
#    Speaker  Season
# 0        *    6824
# 1   Howard    4960
# 2  Leonard    7746
# 3    Penny    6149
# 4      Raj    4048
# 5  Sheldon    9191

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
sr = pd.Series (['Sheldon','Howard','Leonard','Penny','Raj'])
idx = ['Season 1', 'Text 2','Text 3','Text 4','Text 5']
sr.index = idx
print(sr)
# Out:
# Season 1    Sheldon
# Text 2       Howard
# Text 3      Leonard
# Text 4        Penny
# Text 5          Raj
# dtype: object

# %%
df.groupby('Location')

# %%
type(df.groupby('Location'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(df.groupby('Speaker'))
# Out:
# [('*',
#                                                 Unnamed: 0 Location Scene Text  \
#   2      2,The room in the basement," Sheldon enters, t...        *     *    *
#   9      9,The same," later,",Oh. A small human wreaks ...        *     *    *
#   10     10,The apartment," The guys are playing a boar...        *     *    *
#   14     14,The hallway," Howard knocks on Penny’s door...        *     *    *
#   20     20,The apartment," The three guys are still ho...        *     *    *
#   ...                                                  ...      ...   ...  ...
#   38908  38908,Outside Penny’s door," Leonard knocks,",...        *     *    *
#   38913  38913,Raj’s apartment," Raj is watching a Boll...        *     *    *
#   38914  38914,The same," later, Leonard is dressed as ...        *     *    *
#   38915  38915,The hospital," Howard runs in and up to ...        *     *    *
#   38917  38917,The apartment," Sheldon has a series of ...        *     *    *
#
# ...

# %%
list(df.groupby('Text'))
# Out:
# [('  Penny.',    Unnamed: 0      Location Scene      Text  Speaker Season;
#   47         47  Penny’s door     *    Penny.  Sheldon      4;),
#  (' Ah it’s Penny.',
#        Unnamed: 0         Location Scene             Text  Speaker Season;
#   8167       8167  Outside the bar     *   Ah it’s Penny.  Leonard      7;),
#  (' Amy.',       Unnamed: 0           Location Scene   Text  Speaker Season;
#   3252        3252    Amy’s apartment     *   Amy.  Sheldon      6;
#   18624      18624    Amy’s apartment     *   Amy.  Sheldon      7;
#   30002      30002  Penny’s apartment     *   Amy.  Sheldon      9;),
#  (' Amy. I made a commitment in writing to comfort you in times like this. Additionally you are my girlfriend and I care about your well-being.',
#         Unnamed: 0         Location Scene  \
#   23826      23826  Amy’s apartment     *
#
#                                                       Text  Speaker Season;
# ...
